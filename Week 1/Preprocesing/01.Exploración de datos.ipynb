# %% [markdown]
# # Exploración de datos

# %% [markdown]
# ### Docente: M.Sc. Richard Fernández

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\msi\anaconda3\envs\spacy\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as ss
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data.shape
# Out:
# (400, 5)

# %%
data.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
#Tipos de variables
#Cualitativas
#Nominal: género, estado civil, etc => object
#Ordinal: nivel socioeconómico, grado de instrucción, etc => object

#Cuantitativas
#Discreta: edad, número de visitas a un banco, etc => int
#Continua: peso, estatura, etc => float

# %%
data.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
#1.Análisis Univariado

#media
data['Age'].mean()
# Out:
# 37.655

# %%
#mediana
data['Age'].median()
# Out:
# 37.0

# %%
#moda
data['Age'].mode()
# Out:
# 0    35
# Name: Age, dtype: int64

# %%
#cuartiles
data['Age'].quantile()
# Out:
# 37.0

# %%
data['Age'].quantile([0])
# Out:
# 0.0    18.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([1])
# Out:
# 1.0    60.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.25])
# Out:
# 0.25    29.75
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.50])
# Out:
# 0.5    37.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.75])
# Out:
# 0.75    46.0
# Name: Age, dtype: float64

# %%
#decil
data['Age'].quantile([0.10])
# Out:
# 0.1    24.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.20])
# Out:
# 0.2    28.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.90])
# Out:
# 0.9    52.1
# Name: Age, dtype: float64

# %%
#rango
data['Age'].min()
# Out:
# 18

# %%
data['Age'].max()
# Out:
# 60

# %%
data['Age'].max()-data['Age'].min()
# Out:
# 42

# %%
#rango intercuartílico
data['Age'].quantile(0.75)-data['Age'].quantile(0.25)
# Out:
# 16.25

# %%
#varianza
data['Age'].var()
# Out:
# 109.89070175438606

# %%
#desviación estándar
data['Age'].std()
# Out:
# 10.48287659730792

# %%
data['Age'].std(ddof=0) #poblacional
# Out:
# 10.469764801560734

# %%
data['Age'].std(ddof=1) #muestral
# Out:
# 10.48287659730792

# %%
#coeficiente de variación => ¿Qué variable tiene mayor dispersión?
data['Age'].std(ddof=0)/data['Age'].mean()
# Out:
# 0.27804447753447703

# %%
#coeficiente de asimetría
ss.skew(data['Age'])
# Out:
# 0.23046904236325927

# %%
#coeficiente de curtosis
ss.kurtosis(data['Age'])
# Out:
# -0.6297213829600437

# %%
#resumen
data['Age'].describe()
# Out:
# count    400.000000
# mean      37.655000
# std       10.482877
# min       18.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
data['EstimatedSalary'].describe()
# Out:
# count       400.000000
# mean      69742.500000
# std       34096.960282
# min       15000.000000
# 25%       43000.000000
# 50%       70000.000000
# 75%       88000.000000
# max      150000.000000
# Name: EstimatedSalary, dtype: float64

# %%
#Prueba de normalidad
#Ho: La variable se aproxima a una distribución normal
#Ha: La variable no se aproxima a una dsitribución normal

#Si el pvalor < 5% => Se rechaza la Ho, al 95% de confianza, las variable no se aproxima a una distribución normal
#Si el pvalor > 5% => No se rechaza la Ho, al 95% de confianza, las variable se aproxima a una distribución normal

ss.shapiro(data.EstimatedSalary)
# Out:
# ShapiroResult(statistic=0.9600138068199158, pvalue=5.734485331032602e-09)

# %%
ss.shapiro(data.Age)
# Out:
# ShapiroResult(statistic=0.9785022735595703, pvalue=1.1644284313661046e-05)

# %%
ss.normaltest(data.EstimatedSalary)
# Out:
# NormaltestResult(statistic=19.18964958710917, pvalue=6.808015523241932e-05)

# %%
ss.normaltest(data.Age)
# Out:
# NormaltestResult(statistic=17.093306246119845, pvalue=0.00019419395640499378)

# %%
#2.Análisis Bivariado
# coeficiente de correlación
# Si las variables se aproximan a una distribución normal => Pearson
# Si las variables no se aproximan a una distribución normal => Spearman
#data.corr()
#data.loc[:,['Age','EstimatedSalary']].corr(method = "pearson")
#data.loc[:,['Age','EstimatedSalary']].corr(method = "kendall")
data.loc[:,['Age','EstimatedSalary']].corr(method = "spearman")
# Out:
#                       Age  EstimatedSalary
# Age              1.000000         0.124824
# EstimatedSalary  0.124824         1.000000

# %%
#Prueba de correlación
#Ho: las variables no están correlacionadas 
#Ha: las variables están correlacionadas

#Si el pvalor < 5% => Se rechaza la Ho, al 95% de confianza, las variables están correlacionadas
#Si el pvalor > 5% => No se rechaza la Ho, al 95% de confianza, las variables no están correlacionadas

# %%
#ss.pearsonr(data['Age'],data['EstimatedSalary'])

# %%
ss.spearmanr(data['Age'],data['EstimatedSalary'])
# Out:
# SignificanceResult(statistic=0.12482434405192087, pvalue=0.01247367042800823)

# %%
#ss.kendalltau(data['Age'],data['EstimatedSalary'])

# %%
#np.corrcoef(data['Age'],data['EstimatedSalary'])

# %%
#3.Visualización de datos

#Histograma
data['Age'].plot(kind='hist',bins=10,title='Age',subplots=True)
plt.show()

# %%
data['Age'].hist(bins=10) 
plt.xlabel("Edad en años")
plt.ylabel("Frecuencia")
plt.show()

# %%
data['EstimatedSalary'].plot(kind='hist',bins=10,title='Salary',subplots=True)
plt.show()

# %%
sns.distplot(data['EstimatedSalary'])
plt.show()
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_33276\671363613.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['EstimatedSalary'])

# %%
#Densidad
data['Age'].plot(kind='density')
plt.show()

# %%
sns.kdeplot(data['Age'])
plt.show()

# %%
sns.kdeplot(data['Age'],shade=True)
plt.show()
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_33276\2542877193.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Age'],shade=True)

# %%
#Boxplot
plt.boxplot(data['Age'])
plt.show()

# %%
sns.boxplot(list(data['Age']))
plt.show()

# %%
sns.boxplot(x='Age',data=data)
plt.show()

# %%
sns.boxplot(y='Age',data=data)
plt.show()

# %%
sns.boxplot(x='Purchased',y='Age',data=data)
plt.show()

# %%
sns.boxplot(x='Purchased',y='EstimatedSalary',data=data)
plt.show()

# %%
#Violin Plot
sns.violinplot(y='Age',data=data)
plt.show()

# %%
sns.violinplot(x='Purchased',y='Age',data=data)
plt.show()

# %%
#Swarm Plot
sns.swarmplot(data['Age'])
plt.show()

# %%
sns.swarmplot(x=data['EstimatedSalary'])
plt.show()

# %%
sns.swarmplot(y=data['EstimatedSalary'])
plt.show()

# %%
sns.swarmplot(y=data['EstimatedSalary'],x=data['Purchased'])
plt.show()

# %%
#Gráfico de dispersión
data.plot(kind='scatter', x='Age', y='EstimatedSalary')
plt.show()

# %%
plt.scatter(data['Age'],data['EstimatedSalary'])
plt.show()

# %%
plt.plot(data['Age'],data['EstimatedSalary'],"ro")
plt.show()

# %%
#Heatmap
sns.heatmap(data.loc[:,['Age','EstimatedSalary']].corr(method = "spearman"))
plt.show()

# %%
#Resumen
sns.pairplot(data.loc[:,['Age','EstimatedSalary']])
plt.show()
# Out:
# c:\Users\MSI\anaconda3\envs\spacy\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Bar Chart
data['Purchased'].value_counts().plot.bar()
plt.show()

# %%
sns.countplot(data['Purchased'])
plt.show()

# %%
#Pie Chart
plt.pie(data['Purchased'].value_counts(),labels=['0','1'])
plt.show()

# %%
print(pd.crosstab(data["Purchased"],data["Gender"]))
Gender = pd.crosstab(data["Purchased"],data["Gender"])
Gender.div(Gender.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True,figsize=(4,4))
plt.xlabel("Purchased")
plt.ylabel("Percentage")
plt.show()
# Out:
# Gender     Female  Male
# Purchased
# 0             127   130
# 1              77    66

# %%
#Prueba Chi-Cuadrado
#Ho: no existe dependencia entre las variables
#Ha: existe dependencia entre las variables

#Si pvalor < 5% => Se rechaza Ho, al 95% de confianza, existe dependencia entre las variables
#Si pvalor > 5% => No se rechaza Ho, al 95% de confianza, no existe dependencia entre las variables

# %%
contigencia = pd.crosstab(data['Purchased'], data['Gender']) 
c, p, dof, expected = chi2_contingency(contigencia) 
print(p)
# Out:
# 0.45624659183130645
